# %%
#Libs necessárias
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings 

warnings.filterwarnings('ignore')

# %%
df_recursos = pd.read_csv('Salary_Data.csv')

df_recursos.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
#Renomeando as colunas 
df_recursos.rename(columns={
    'YearsExperience' : 'XP',
    'Salary' : 'Renda'

},inplace=True)

# %%
df_recursos
# Out:
#       XP     Renda
# 0    1.1   39343.0
# 1    1.3   46205.0
# 2    1.5   37731.0
# 3    2.0   43525.0
# 4    2.2   39891.0
# 5    2.9   56642.0
# 6    3.0   60150.0
# 7    3.2   54445.0
# 8    3.2   64445.0
# 9    3.7   57189.0
# 10   3.9   63218.0
# 11   4.0   55794.0
# 12   4.0   56957.0
# 13   4.1   57081.0
# 14   4.5   61111.0
# 15   4.9   67938.0
# 16   5.1   66029.0
# 17   5.3   83088.0
# 18   5.9   81363.0
# 19   6.0   93940.0
# 20   6.8   91738.0
# 21   7.1   98273.0
# 22   7.9  101302.0
# 23   8.2  113812.0
# 24   8.7  109431.0
# 25   9.0  105582.0
# 26   9.5  116969.0
# 27   9.6  112635.0
# 28  10.3  122391.0
# 29  10.5  121872.0

# %%
df_recursos.shape
# Out:
# (30, 2)

# %%
#Campos Nulos
df_recursos.isnull().sum()
# Out:
# XP       0
# Renda    0
# dtype: int64

# %%
#Gráfico 
sns.heatmap(df_recursos.isnull(),cbar=False)
# Out:
# <AxesSubplot: >

# %%
df_recursos.describe()
# Out:
#               XP          Renda
# count  30.000000      30.000000
# mean    5.313333   76003.000000
# std     2.837888   27414.429785
# min     1.100000   37731.000000
# 25%     3.200000   56720.750000
# 50%     4.700000   65237.000000
# 75%     7.700000  100544.750000
# max    10.500000  122391.000000

# %%
#Tamnho
plt.figure(figsize=(10,6))

#Título
plt.title('Analise de Renda')

#Gráfico
sns.kdeplot(df_recursos['Renda']);

# %%
#Tamanho 
plt.figure(figsize=(10,6))

#Distribuição 
sns.boxplot(df_recursos['Renda'])
# Out:
# <AxesSubplot: ylabel='Renda'>

# %%
#Tamanho 
plt.figure(figsize=(10,6))

#Distribuição 
sns.boxplot(df_recursos['XP'])
# Out:
# <AxesSubplot: ylabel='XP'>

# %%
#Distribuição 
sns.scatterplot(data=df_recursos,x='Renda',y='XP')
# Out:
# <AxesSubplot: xlabel='Renda', ylabel='XP'>

# %%
sns.regplot(data=df_recursos,x='Renda',y='XP')
# Out:
# <AxesSubplot: xlabel='Renda', ylabel='XP'>

# %%
#Correlação 
Correlacao = df_recursos.corr()
sns.heatmap(Correlacao)
# Out:
# <AxesSubplot: >

# %%
#Correlação 
Correlacao = df_recursos.corr()

plt.figure(figsize=(10,6))

sns.heatmap(Correlacao,annot=True,cbar=True)
# Out:
# <AxesSubplot: >
