# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# Lib para ignorar avisos
import warnings

# Desabilitando avisos
warnings.filterwarnings('ignore')

# %%
#Lendo o arquivo de Games
arq_games = pd.read_csv('PS4_GamesSales.csv',encoding='latin-1')

arq_games
# Out:
#                                     Game    Year             Genre  \
# 0                     Grand Theft Auto V  2014.0            Action
# 1              Call of Duty: Black Ops 3  2015.0           Shooter
# 2                  Red Dead Redemption 2  2018.0  Action-Adventure
# 3                     Call of Duty: WWII  2017.0           Shooter
# 4                                FIFA 18  2017.0            Sports
# ...                                  ...     ...               ...
# 1029  Fallen Legion: Flames of Rebellion     NaN      Role-Playing
# 1030            Radial G Racing Revolved  2017.0            Racing
# 1031                The Mummy Demastered     NaN            Action
# 1032          Project Nimbus: Code Mirai     NaN            Action
# 1033                 Battle Chef Brigade     NaN            Action
#
#            Publisher  North America  Europe  Japan  Rest of World  Global
# 0     Rockstar Games           6.06    9.71   0.60           3.02   19.39
# ...

# %%
arq_games.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
#Dimensão 
arq_games.shape
# Out:
# (1034, 9)

# %%
#Nulos 
arq_games.isnull().sum()
# Out:
# Game               0
# Year             209
# Genre              0
# Publisher        209
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
#Nulos Gráficos 
plt.figure(figsize=(15,6))
plt.title('Analisando os Campos Nulos')
sns.heatmap(arq_games.isnull(),cbar=False)
# Out:
# <AxesSubplot: title={'center': 'Analisando os Campos Nulos'}>

# %%
arq_games.dropna()
# Out:
#                            Game    Year             Genre  \
# 0            Grand Theft Auto V  2014.0            Action
# 1     Call of Duty: Black Ops 3  2015.0           Shooter
# 2         Red Dead Redemption 2  2018.0  Action-Adventure
# 3            Call of Duty: WWII  2017.0           Shooter
# 4                       FIFA 18  2017.0            Sports
# ...                         ...     ...               ...
# 1025                  Biomutant  2019.0            Action
# 1026                    de Blob  2017.0          Platform
# 1027           Chaos on Deponia  2017.0         Adventure
# 1028                  Code Vein  2018.0            Action
# 1030   Radial G Racing Revolved  2017.0            Racing
#
#                        Publisher  North America  Europe  Japan  Rest of World  \
# 0                 Rockstar Games           6.06    9.71   0.60           3.02
# 1                     Activision           6.18    6.05   0.41           2.44
# ...

# %%
#Retirando dados nulos 
arq_games.dropna(inplace=True)

# %%
#Estatistica
arq_games.describe()
# Out:
#               Year  North America      Europe       Japan  Rest of World  \
# count   825.000000     825.000000  825.000000  825.000000     825.000000
# mean   2015.966061       0.256448    0.311600    0.042048       0.111552
# std       1.298360       0.620259    0.868271    0.119814       0.274713
# min    2013.000000       0.000000    0.000000    0.000000       0.000000
# 25%    2015.000000       0.000000    0.000000    0.000000       0.000000
# 50%    2016.000000       0.050000    0.020000    0.000000       0.020000
# 75%    2017.000000       0.190000    0.220000    0.040000       0.090000
# max    2020.000000       6.180000    9.710000    2.170000       3.020000
#
#            Global
# count  825.000000
# mean     0.721721
# std      1.743122
# min      0.000000
# 25%      0.030000
# 50%      0.120000
# 75%      0.560000
# max     19.390000

# %%
plt.figure(figsize=(15,6))

#Título
plt.title('Quantidade de Vendas Globais (mi)',loc='left',fontsize=14)

#label
plt.ylabel('Quantidade Vendas (mi)')

#Gráfico
sns.barplot(data=arq_games,x='Year',y='Global',ci=None,estimator=sum);

# %%
#Retirar os Anos 
arq_games=arq_games.loc[(arq_games['Year'] != 2019 ) & (arq_games['Year'] != 2020)]

arq_games.head()
# Out:
#                         Game    Year             Genre       Publisher  \
# 0         Grand Theft Auto V  2014.0            Action  Rockstar Games
# 1  Call of Duty: Black Ops 3  2015.0           Shooter      Activision
# 2      Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 3         Call of Duty: WWII  2017.0           Shooter      Activision
# 4                    FIFA 18  2017.0            Sports       EA Sports
#
#    North America  Europe  Japan  Rest of World  Global
# 0           6.06    9.71   0.60           3.02   19.39
# 1           6.18    6.05   0.41           2.44   15.09
# 2           5.26    6.21   0.21           2.26   13.94
# 3           4.67    6.21   0.40           2.12   13.40
# 4           1.27    8.64   0.15           1.73   11.80

# %%
#Tamanho 
plt.figure(figsize=(12,5))

#Estilo 
plt.style.use('ggplot')

#Titulo 
plt.title('Distribuição das Vendas Globais',loc='left')

sns.kdeplot(arq_games['Global'])
# Out:
# <AxesSubplot: title={'left': 'Distribuição das Vendas Globais'}, xlabel='Global', ylabel='Density'>
