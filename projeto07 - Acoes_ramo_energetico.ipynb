# %%
# Bibliotecas
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Lendo a base de dados
df_energia = pd.read_excel('Dados_Empresas_Energia.xlsx')

# Verificando
df_energia.head()
# Out:
#         Data  Petrobras  Aeris Energy     Alupar  AES Brasil      Cemig  \
# 0 2021-03-22  23.080000          9.28  24.600000       31.10  11.040665
# 1 2021-03-23  22.549999          8.94  24.910000       30.75  11.040665
# 2 2021-03-24  22.530001          9.02  24.610001       30.00  10.816444
# 3 2021-03-25  22.959999          9.20  24.990000       30.77  11.157260
# 4 2021-03-26  23.299999          9.10  25.299999       30.27  11.148292
#
#         Cesp
# 0  27.980000
# 1  27.700001
# 2  27.330000
# 3  27.809999
# 4  28.090000

# %%
#Gráfico 

#Estilo do gráfico 

plt.style.use('seaborn-darkgrid')

#Tamanho 
plt.figure(figsize=(16,7))

#Titulo 
plt.title('Analise de Ações de Empresas no Segmento de Energia',loc='left',fontsize=18, fontweight=0 )

#Plot da Petrobras 

plt.plot(df_energia.index,df_energia['Petrobras'], color='#008c4a', linewidth=4, alpha=0.7)

#Texto da Petrobrás 
plt.text(df_energia.index[-1],df_energia['Petrobras'].tail(1),'Petrobras', color='#008c4a', size='large', horizontalalignment='left')


#plot todas as colunas 
for Coluna in df_energia.columns[1:]:
    #Plot ouras ações
    plt.plot(df_energia.index,df_energia[Coluna], color='gray', linewidth=2, alpha=0.7)

    #Texto das outras Ações
    plt.text(df_energia.index[-1],df_energia[Coluna].tail(1),Coluna, color='gray', size='large', horizontalalignment='left')


#Labels 
plt.xlabel('Periodo')
plt.ylabel('Preço de Fechamento:(R$)')
# Out:
# C:\Users\walla\AppData\Local\Temp\ipykernel_32400\966284284.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# Text(0, 0.5, 'Preço de Fechamento:(R$)')
